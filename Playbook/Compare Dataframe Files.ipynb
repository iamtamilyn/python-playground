# %%
import pandas as pd
import os
from datetime import date, datetime
import csv

# %%
widths = [
    9, # Retiree SSN
    9, # Member SSN
    20, # Member First Name
    20, # Member Last Name
    8, # Member Date of Birth
    1, # Member Gender
    8, # Enrollment Effective Date
    8, # Enrollment Term Date
    1, # Member Relation Code
    10, # Phone Number
    40, # Address 1
    40, # Address 2
    30, # City
    2, # State
    10, # Zip Code
    60, # Email Address
    8, # Medicare A Start Date
    8, # Medicare B Start Date
    12, # Member HICN
    8, # OGB Member ID
    8, # Death Date
    8, # Divorce Date
    8, # Report Date
]

# %%
filename1 = r"C:\Users\tape\Desktop\Python\ODE\LouisianaOGBQualifiedFundedTimePeriods_2020-05-15.txt"
filename2 = r"C:\Users\tape\Desktop\Python\TestLouisianaDev.txt"

# %%
df1 = pd.read_fwf(filename1, header=None, widths=widths, dtype = "object")
df1
# Out:
#             0          1         2            3         4  5         6    7   \
# 0    437522941  434486377   Septime  PffjSaceDev  19350515  M  20130101  NaN
# 1    437522941  437522941     Doris  PffjDfbjDev  19371124  F  20130101  NaN
# 2    157441353  157441353  Kathleen  PdjjKcdeDev  19510317  F  20160301  NaN
# 3    438266661  438266661    Yvonne  JebjYaejDev  19241012  F  20150101  NaN
# 4    438365088  438365088    JOELLA  WebjJdjjDev  19260624  F  20150101  NaN
# ..         ...        ...       ...          ...       ... ..       ...  ...
# 686  435907914  435907914     Vicky  BbjjVbjjDev  19511209  F  20170101  NaN
# 687  438863998  438863998    Carmen  LajjCfeeDev  19511229  F  20161201  NaN
# 688  433863432  433863432      GARY  AbejGfjjDev  19510919  M  20161001  NaN
# 689  435828376  435828376     GAYLA  SebbGdjjDev  19490110  F  20161101  NaN
# 690  433905051  439646727     Larry  PfbjLfjjDev  19460803  M  20161101  NaN
#
# ...

# %%
df2 = pd.read_fwf(filename2, header=None, widths=widths, dtype = "object")
df2
# Out:
#             0          1         2            3         4  5         6    7   \
# 0    437522941  434486377   Septime  PffjSaceDev  19350515  M  20130101  NaN
# 1    437522941  437522941     Doris  PffjDfbjDev  19371124  F  20130101  NaN
# 2    157441353  157441353  Kathleen  PdjjKcdeDev  19510317  F  20160301  NaN
# 3    438266661  438266661    Yvonne  JebjYaejDev  19241012  F  20150101  NaN
# 4    438365088  438365088    JOELLA  WebjJdjjDev  19260624  F  20150101  NaN
# ..         ...        ...       ...          ...       ... ..       ...  ...
# 686  435907914  435907914     Vicky  BbjjVbjjDev  19511209  F  20170101  NaN
# 687  438863998  438863998    Carmen  LajjCfeeDev  19511229  F  20161201  NaN
# 688  433863432  433863432      GARY  AbejGfjjDev  19510919  M  20161001  NaN
# 689  435828376  435828376     GAYLA  SebbGdjjDev  19490110  F  20161101  NaN
# 690  433905051  439646727     Larry  PfbjLfjjDev  19460803  M  20161101  NaN
#
# ...

# %%
df2[22] = "20200527"

# %%
df2
# Out:
#             0          1         2            3         4  5         6    7   \
# 0    437522941  434486377   Septime  PffjSaceDev  19350515  M  20130101  NaN
# 1    437522941  437522941     Doris  PffjDfbjDev  19371124  F  20130101  NaN
# 2    157441353  157441353  Kathleen  PdjjKcdeDev  19510317  F  20160301  NaN
# 3    438266661  438266661    Yvonne  JebjYaejDev  19241012  F  20150101  NaN
# 4    438365088  438365088    JOELLA  WebjJdjjDev  19260624  F  20150101  NaN
# ..         ...        ...       ...          ...       ... ..       ...  ...
# 686  435907914  435907914     Vicky  BbjjVbjjDev  19511209  F  20170101  NaN
# 687  438863998  438863998    Carmen  LajjCfeeDev  19511229  F  20161201  NaN
# 688  433863432  433863432      GARY  AbejGfjjDev  19510919  M  20161001  NaN
# 689  435828376  435828376     GAYLA  SebbGdjjDev  19490110  F  20161101  NaN
# 690  433905051  439646727     Larry  PfbjLfjjDev  19460803  M  20161101  NaN
#
# ...

# %%
df1.equals(df2)
# Out:
# True
