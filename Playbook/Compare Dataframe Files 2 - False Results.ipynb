# %%
import pandas as pd

# %%
folder_path = r"\\fileshare\Department Shares\Client Integration\Client Documents and Eligibility Files\Portland General Electric\Populations Summary & Config Spec"
prev_file = folder_path + "\\Configuration Specifications - PGE - 02-27-20.xlsm"
#"\\fileshare\Department Shares\Client Integration\Client Documents and Eligibility Files\Portland General Electric\Populations Summary & Config Spec\Configuration Specifications - PGE - 02-27-20.xlsm"
new_file = folder_path + "\\Configuration Specifications - PGE - 06-12-2020.xlsm"

# %%
sheetname = "7 Medicare Segment Settings"
sheetname = "6 Non-Medicare Segment Settings"

# %%
df1 = pd.read_excel(prev_file, sheet_name = sheetname, header= None, dtype="object")
df2 = pd.read_excel(new_file, sheet_name = sheetname, header= None, dtype="object")
df1.fillna("", inplace=True)
df2.fillna("", inplace=True)
df1.equals(df2)
# Out:
# False

# %%
colnumber = 0
df1[colnumber].equals(df2[colnumber])
# Out:
# False

# %%
colnumber = 0
for x in range(0,21):
    print(x, ":", df1[colnumber][x] == df2[colnumber][x])
# Out:
# 0 : True
# 1 : True
# 2 : True
# 3 : True
# 4 : True
# 5 : True
# 6 : True
# 7 : True
# 8 : True
# 9 : True
# 10 : True
# 11 : True
# 12 : True
# 13 : True
# 14 : True
# 15 : True
# 16 : True
# 17 : True
# 18 : True
# 19 : False
# 20 : True

# %%
rownum = 19
df1[colnumber][rownum] == df2[colnumber][rownum]
# Out:
# False

# %%
df1[colnumber][19]
# Out:
# 'Q: What if the primary is Medicare eligible but the spouse is non-Medicare eligible?\nA: Since the primary is Medicare eligible, he or she can qualify for the HRA by meeting the qualification requirements defined by PGE and administered by Willis Towers Watson. If the spouse is eligible for funding, he or she will have the option to activate funding until becoming Medicare eligible.\nQ: Can participants in a household make independent funding activation decisions?\nA: Yes. Although we do not encourage it, this is a decision that each individual in the household can make separately.\nQ: What happens if they do not enroll when non-Medicare eligible?\nA: Enrollment requirements can’t be enforced for non-Medicare Eligibles. They must inform their benefit advisor of their decision to activate their HRA. Activation decisions as a non-Medicare participant will not impact HRA eligibility once they become Medicare eligible.\nQ: If they do not activate their funding as a non-Medicare eligible
# ...

# %%
df1
# Out:
#                                                     0  \
# 0                                                 NaN
# 1    Non-Medicare IFP Campaign Segment Level Settings
# 2                                           Section 1
# 3                                                   a
# 4                                                   b
# 5                                                   c
# 6                                           Section 2
# 7                                                   a
# 8                                                   b
# 9                                                   c
# 10                                                NaN
# 11                                                  d
# 12                                                  e
# 13                                                  f
# 14                                          Section 3
# 15  Willis Towers Watson administers funding for P...
# ...

# %%
df2
# Out:
#                                                     0  \
# 0                                                 NaN
# 1    Non-Medicare IFP Campaign Segment Level Settings
# 2                                           Section 1
# 3                                                   a
# 4                                                   b
# 5                                                   c
# 6                                           Section 2
# 7                                                   a
# 8                                                   b
# 9                                                   c
# 10                                                NaN
# 11                                                  d
# 12                                                  e
# 13                                                  f
# 14                                          Section 3
# 15  Willis Towers Watson administers funding for P...
# ...

# %%
df1.equals(df2)
# Out:
# True
